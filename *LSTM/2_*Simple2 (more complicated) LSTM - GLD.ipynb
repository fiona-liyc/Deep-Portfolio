# %% [markdown]
# ## Tutorial soures
# https://www.kaggle.com/ternaryrealm/lstm-time-series-explorations-with-keras
# ![Screen%20Shot%202019-09-03%20at%2011.52.10%20PM.png](attachment:Screen%20Shot%202019-09-03%20at%2011.52.10%20PM.png)
# ![Screen%20Shot%202019-09-03%20at%2011.12.05%20PM.png](attachment:Screen%20Shot%202019-09-03%20at%2011.12.05%20PM.png)

# %% [markdown]
# ## Libs

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import matplotlib as matpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import math
import seaborn as sns


# Using the Tensorflow backend (default).
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Activation, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split


matpl.rcParams['figure.figsize'] = (20, 15)
plt.style.use('seaborn-darkgrid')
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data

# %%
# %store -r data_GLD
data_GLD.head(2)
# Out:
#             Adj Close
# Date
# 2009-06-01  93.709999
# 2009-06-08  92.169998

# %%
data_GLD.plot(figsize=(15,10))

# %%
mm = MinMaxScaler(feature_range = (0,1))

# %%
#scale data between 0 1 to enhance numerical stability
dataset = mm.fit_transform(data_GLD)

# %%
#visualize a dataset[0:2]few data
dataset[0:2]
# Out:
# array([[0.04409563],
#        [0.02765317]])

# %% [markdown]
# 1 data every week. 52 data per year, 522 data in total.
# * use the past 2 months (8 weeks) to predict 1 week ahead.
# * create window of last 8 obs to train model
# Parameters:
# * history_size - size of past window
# * target_size - how far in future model should learn to predict

# %% [markdown]
# 6 years of training data = 313 weeks.
# Rest of the 209 weeks are for validation.

# %%
split_size = 0.6

train_size = int(len(dataset) * split_size)
test_size = len(dataset) - train_size

train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

print("Number of entries (training set, test set): " + str((len(train), len(test))))
# Out:
# Number of entries (training set, test set): (313, 209)

# %%
def create_dataset(dataset, window_size):
    data_X, data_Y = [], []
    for i in range(len(dataset) - window_size - 1):
        a = dataset[i:(i + window_size), 0]
        data_X.append(a)
        data_Y.append(dataset[i + window_size, 0])
    return(np.array(data_X), np.array(data_Y))

# %%
# Create test and train sets for one-step-ahead regression.
window_size = 1

train_X, train_Y = create_dataset(train, window_size)
test_X, test_Y = create_dataset(test, window_size)
print("Original training data shape:")
print(train_X.shape)

# Reshape the input data into appropriate form for Keras.
train_X = np.reshape(train_X, (train_X.shape[0], 1, train_X.shape[1]))
test_X = np.reshape(test_X, (test_X.shape[0], 1, test_X.shape[1]))
print("New training data shape:")
print(train_X.shape)
# Out:
# Original training data shape:
# (311, 1)
# New training data shape:
# (311, 1, 1)

# %% [markdown]
# ## Univar Forecasting Model
#
# According to Keras documentation, validation is done as such:
# * "validation_split: Float between 0 and 1. Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. The validation data is selected from the last samples in the x and y data provided, before shuffling."
#
# LSTM model
# * One input later
# * 2 LSTM hidden layers: first with 64 blocks, second with 32 blocks
# * Dense layer to give single output
# * MSE as loss function

# %%
NUM_NEURONS_FirstLayer = 64
NUM_NEURONS_SecondLayer = 32
EPOCHS = 200

#Build the model
def fit_model(train_X, train_Y, window_size):
    history = []
    model = Sequential()
    model.add(LSTM(NUM_NEURONS_FirstLayer,input_shape=(1, window_size), return_sequences=True))
    model.add(LSTM(NUM_NEURONS_SecondLayer,input_shape=(NUM_NEURONS_FirstLayer,1)))
    model.add(Dropout(0.1))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')

    model.fit(train_X,train_Y,validation_split = 0.1,epochs=EPOCHS,shuffle=True,batch_size=25, verbose=2)
    return(model)

model1 = fit_model(train_X, train_Y, window_size)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0904 01:54:59.126525 4572415424 deprecation_wrapper.py:119] From //anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0904 01:54:59.152970 4572415424 deprecation_wrapper.py:119] From //anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0904 01:54:59.154807 4572415424 deprecation_wrapper.py:119] From //anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0904 01:54:59.497524 4572415424 deprecation_wrapper.py:119] From //anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0904 01:54:59.502485 4572415424 deprecation.py:506] From //anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0904 01:54:59.519200 4572415424 deprecation_wrapper.py:119] From //anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0904 01:54:59.696490 4572415424 deprecation.py:323] From //anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0904 01:55:00.463401 4572415424 deprecation_wrapper.py:119] From //anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 279 samples, validate on 32 samples
# Epoch 1/200
#  - 4s - loss: 0.2730 - val_loss: 0.0533
# Epoch 2/200
#  - 0s - loss: 0.2145 - val_loss: 0.0285
# Epoch 3/200
#  - 0s - loss: 0.1488 - val_loss: 0.0078
# Epoch 4/200
#  - 0s - loss: 0.0825 - val_loss: 0.0016
# Epoch 5/200
#  - 0s - loss: 0.0340 - val_loss: 0.0208
# Epoch 6/200
#  - 0s - loss: 0.0238 - val_loss: 0.0351
# Epoch 7/200
#  - 0s - loss: 0.0226 - val_loss: 0.0236
# Epoch 8/200
#  - 0s - loss: 0.0191 - val_loss: 0.0167
# Epoch 9/200
#  - 0s - loss: 0.0169 - val_loss: 0.0177
# Epoch 10/200
#  - 0s - loss: 0.0157 - val_loss: 0.0157
# Epoch 11/200
#  - 0s - loss: 0.0135 - val_loss: 0.0126
# Epoch 12/200
#  - 0s - loss: 0.0111 - val_loss: 0.0092
# Epoch 13/200
#  - 0s - loss: 0.0091 - val_loss: 0.0082
# Epoch 14/200
#  - 0s - loss: 0.0076 - val_loss: 0.0065
# Epoch 15/200
#  - 0s - loss: 0.0064 - val_loss: 0.0054
# Epoch 16/200
#  - 0s - loss: 0.0054 - val_loss: 0.0034
# Epoch 17/200
#  - 0s - loss: 0.0046 - val_loss: 0.0033
# Epoch 18/200
#  - 0s - loss: 0.0046 - val_loss: 0.0020
# Epoch 19/200
#  - 0s - loss: 0.0032 - val_loss: 0.0015
# Epoch 20/200
#  - 0s - loss: 0.0032 - val_loss: 0.0011
# Epoch 21/200
#  - 0s - loss: 0.0031 - val_loss: 9.2569e-04
# Epoch 22/200
#  - 0s - loss: 0.0030 - val_loss: 7.3175e-04
# Epoch 23/200
#  - 0s - loss: 0.0027 - val_loss: 6.1076e-04
# Epoch 24/200
#  - 0s - loss: 0.0030 - val_loss: 6.4397e-04
# Epoch 25/200
#  - 0s - loss: 0.0030 - val_loss: 6.1515e-04
# Epoch 26/200
#  - 0s - loss: 0.0029 - val_loss: 6.2025e-04
# Epoch 27/200
#  - 0s - loss: 0.0027 - val_loss: 6.1537e-04
# Epoch 28/200
#  - 0s - loss: 0.0029 - val_loss: 6.4266e-04
# Epoch 29/200
#  - 0s - loss: 0.0032 - val_loss: 6.1933e-04
# Epoch 30/200
#  - 0s - loss: 0.0023 - val_loss: 6.1123e-04
# Epoch 31/200
#  - 0s - loss: 0.0025 - val_loss: 6.4950e-04
# Epoch 32/200
#  - 0s - loss: 0.0029 - val_loss: 6.1124e-04
# Epoch 33/200
#  - 0s - loss: 0.0030 - val_loss: 6.6136e-04
# Epoch 34/200
#  - 0s - loss: 0.0025 - val_loss: 6.2162e-04
# Epoch 35/200
#  - 0s - loss: 0.0024 - val_loss: 6.1470e-04
# Epoch 36/200
#  - 0s - loss: 0.0029 - val_loss: 6.3849e-04
# Epoch 37/200
#  - 0s - loss: 0.0031 - val_loss: 6.1767e-04
# Epoch 38/200
#  - 0s - loss: 0.0027 - val_loss: 6.1681e-04
# Epoch 39/200
#  - 0s - loss: 0.0025 - val_loss: 6.3242e-04
# Epoch 40/200
#  - 0s - loss: 0.0025 - val_loss: 6.4364e-04
# Epoch 41/200
#  - 0s - loss: 0.0027 - val_loss: 6.3008e-04
# Epoch 42/200
#  - 0s - loss: 0.0025 - val_loss: 6.2635e-04
# Epoch 43/200
#  - 0s - loss: 0.0022 - val_loss: 7.3879e-04
# Epoch 44/200
#  - 0s - loss: 0.0025 - val_loss: 6.2398e-04
# Epoch 45/200
#  - 0s - loss: 0.0025 - val_loss: 6.4583e-04
# Epoch 46/200
#  - 0s - loss: 0.0025 - val_loss: 6.4804e-04
# Epoch 47/200
#  - 0s - loss: 0.0025 - val_loss: 6.3834e-04
# Epoch 48/200
#  - 0s - loss: 0.0029 - val_loss: 6.3619e-04
# Epoch 49/200
#  - 0s - loss: 0.0026 - val_loss: 6.2677e-04
# Epoch 50/200
#  - 0s - loss: 0.0025 - val_loss: 6.2346e-04
# Epoch 51/200
#  - 0s - loss: 0.0025 - val_loss: 6.2639e-04
# Epoch 52/200
#  - 0s - loss: 0.0028 - val_loss: 6.5446e-04
# Epoch 53/200
#  - 0s - loss: 0.0026 - val_loss: 6.2407e-04
# Epoch 54/200
#  - 0s - loss: 0.0026 - val_loss: 6.2589e-04
# Epoch 55/200
#  - 0s - loss: 0.0026 - val_loss: 6.4232e-04
# Epoch 56/200
#  - 0s - loss: 0.0025 - val_loss: 6.9430e-04
# Epoch 57/200
#  - 0s - loss: 0.0023 - val_loss: 6.2920e-04
# Epoch 58/200
#  - 0s - loss: 0.0025 - val_loss: 6.2909e-04
# Epoch 59/200
#  - 0s - loss: 0.0027 - val_loss: 6.4711e-04
# Epoch 60/200
#  - 0s - loss: 0.0024 - val_loss: 6.3358e-04
# Epoch 61/200
#  - 0s - loss: 0.0025 - val_loss: 6.3120e-04
# Epoch 62/200
#  - 0s - loss: 0.0024 - val_loss: 6.7931e-04
# Epoch 63/200
#  - 0s - loss: 0.0025 - val_loss: 6.3876e-04
# Epoch 64/200
#  - 0s - loss: 0.0025 - val_loss: 6.4105e-04
# Epoch 65/200
#  - 0s - loss: 0.0026 - val_loss: 6.4733e-04
# Epoch 66/200
#  - 0s - loss: 0.0025 - val_loss: 6.8580e-04
# Epoch 67/200
#  - 0s - loss: 0.0026 - val_loss: 6.3474e-04
# Epoch 68/200
#  - 0s - loss: 0.0023 - val_loss: 6.3099e-04
# Epoch 69/200
#  - 0s - loss: 0.0027 - val_loss: 7.2252e-04
# Epoch 70/200
#  - 0s - loss: 0.0026 - val_loss: 6.4941e-04
# Epoch 71/200
#  - 0s - loss: 0.0026 - val_loss: 6.8459e-04
# Epoch 72/200
#  - 0s - loss: 0.0021 - val_loss: 6.7684e-04
# Epoch 73/200
#  - 0s - loss: 0.0026 - val_loss: 6.4151e-04
# Epoch 74/200
#  - 0s - loss: 0.0027 - val_loss: 6.3112e-04
# Epoch 75/200
#  - 0s - loss: 0.0023 - val_loss: 7.3021e-04
# Epoch 76/200
#  - 0s - loss: 0.0022 - val_loss: 6.3802e-04
# Epoch 77/200
#  - 0s - loss: 0.0024 - val_loss: 6.7402e-04
# Epoch 78/200
#  - 0s - loss: 0.0026 - val_loss: 6.5270e-04
# Epoch 79/200
#  - 0s - loss: 0.0026 - val_loss: 7.0128e-04
# Epoch 80/200
#  - 0s - loss: 0.0025 - val_loss: 6.7544e-04
# Epoch 81/200
#  - 0s - loss: 0.0026 - val_loss: 6.8078e-04
# Epoch 82/200
#  - 0s - loss: 0.0026 - val_loss: 6.7344e-04
# Epoch 83/200
#  - 0s - loss: 0.0023 - val_loss: 6.8199e-04
# Epoch 84/200
#  - 0s - loss: 0.0023 - val_loss: 6.6131e-04
# Epoch 85/200
#  - 0s - loss: 0.0025 - val_loss: 6.7470e-04
# Epoch 86/200
#  - 0s - loss: 0.0021 - val_loss: 6.6507e-04
# Epoch 87/200
#  - 0s - loss: 0.0023 - val_loss: 6.7081e-04
# Epoch 88/200
#  - 0s - loss: 0.0023 - val_loss: 6.5681e-04
# Epoch 89/200
#  - 0s - loss: 0.0022 - val_loss: 6.5417e-04
# Epoch 90/200
#  - 0s - loss: 0.0022 - val_loss: 6.5050e-04
# Epoch 91/200
#  - 0s - loss: 0.0027 - val_loss: 7.0958e-04
# Epoch 92/200
#  - 0s - loss: 0.0024 - val_loss: 6.4951e-04
# Epoch 93/200
#  - 0s - loss: 0.0024 - val_loss: 8.5368e-04
# Epoch 94/200
#  - 0s - loss: 0.0027 - val_loss: 6.4454e-04
# Epoch 95/200
#  - 0s - loss: 0.0028 - val_loss: 7.7494e-04
# Epoch 96/200
#  - 0s - loss: 0.0022 - val_loss: 6.7574e-04
# Epoch 97/200
#  - 0s - loss: 0.0019 - val_loss: 7.3659e-04
# Epoch 98/200
#  - 0s - loss: 0.0022 - val_loss: 6.5149e-04
# Epoch 99/200
#  - 0s - loss: 0.0022 - val_loss: 6.8538e-04
# Epoch 100/200
#  - 0s - loss: 0.0020 - val_loss: 6.4935e-04
# Epoch 101/200
#  - 0s - loss: 0.0021 - val_loss: 8.2866e-04
# Epoch 102/200
#  - 0s - loss: 0.0022 - val_loss: 6.8821e-04
# Epoch 103/200
#  - 0s - loss: 0.0021 - val_loss: 9.1529e-04
# Epoch 104/200
#  - 0s - loss: 0.0023 - val_loss: 6.6051e-04
# Epoch 105/200
#  - 0s - loss: 0.0025 - val_loss: 6.6022e-04
# Epoch 106/200
#  - 0s - loss: 0.0020 - val_loss: 7.1589e-04
# Epoch 107/200
#  - 0s - loss: 0.0023 - val_loss: 6.5235e-04
# Epoch 108/200
#  - 0s - loss: 0.0020 - val_loss: 7.0197e-04
# Epoch 109/200
#  - 0s - loss: 0.0023 - val_loss: 6.6528e-04
# Epoch 110/200
#  - 0s - loss: 0.0022 - val_loss: 6.8978e-04
# Epoch 111/200
#  - 0s - loss: 0.0021 - val_loss: 7.1332e-04
# Epoch 112/200
#  - 0s - loss: 0.0021 - val_loss: 7.2605e-04
# Epoch 113/200
#  - 0s - loss: 0.0021 - val_loss: 6.6005e-04
# Epoch 114/200
#  - 0s - loss: 0.0020 - val_loss: 7.1286e-04
# Epoch 115/200
#  - 0s - loss: 0.0020 - val_loss: 6.6042e-04
# Epoch 116/200
#  - 0s - loss: 0.0020 - val_loss: 6.6013e-04
# Epoch 117/200
#  - 0s - loss: 0.0023 - val_loss: 7.0608e-04
# Epoch 118/200
#  - 0s - loss: 0.0022 - val_loss: 6.7176e-04
# Epoch 119/200
#  - 0s - loss: 0.0025 - val_loss: 8.1370e-04
# Epoch 120/200
#  - 0s - loss: 0.0023 - val_loss: 7.5222e-04
# Epoch 121/200
#  - 0s - loss: 0.0024 - val_loss: 8.0044e-04
# Epoch 122/200
#  - 0s - loss: 0.0023 - val_loss: 6.6507e-04
# Epoch 123/200
#  - 0s - loss: 0.0021 - val_loss: 6.7545e-04
# Epoch 124/200
#  - 0s - loss: 0.0020 - val_loss: 6.6717e-04
# Epoch 125/200
#  - 0s - loss: 0.0022 - val_loss: 6.7997e-04
# Epoch 126/200
#  - 0s - loss: 0.0021 - val_loss: 6.7239e-04
# Epoch 127/200
#  - 0s - loss: 0.0021 - val_loss: 6.7549e-04
# Epoch 128/200
#  - 0s - loss: 0.0021 - val_loss: 6.6255e-04
# Epoch 129/200
#  - 0s - loss: 0.0020 - val_loss: 7.5757e-04
# Epoch 130/200
#  - 0s - loss: 0.0021 - val_loss: 6.7710e-04
# Epoch 131/200
#  - 0s - loss: 0.0019 - val_loss: 6.9097e-04
# Epoch 132/200
#  - 0s - loss: 0.0022 - val_loss: 6.7143e-04
# Epoch 133/200
#  - 0s - loss: 0.0021 - val_loss: 6.8736e-04
# Epoch 134/200
#  - 0s - loss: 0.0023 - val_loss: 7.5776e-04
# Epoch 135/200
#  - 0s - loss: 0.0024 - val_loss: 6.8104e-04
# Epoch 136/200
#  - 0s - loss: 0.0021 - val_loss: 8.6560e-04
# Epoch 137/200
#  - 0s - loss: 0.0019 - val_loss: 6.6887e-04
# Epoch 138/200
#  - 0s - loss: 0.0021 - val_loss: 7.3303e-04
# Epoch 139/200
#  - 0s - loss: 0.0026 - val_loss: 6.9197e-04
# Epoch 140/200
#  - 0s - loss: 0.0020 - val_loss: 7.3663e-04
# Epoch 141/200
#  - 0s - loss: 0.0022 - val_loss: 6.7677e-04
# Epoch 142/200
#  - 0s - loss: 0.0023 - val_loss: 7.0878e-04
# Epoch 143/200
#  - 0s - loss: 0.0022 - val_loss: 6.7813e-04
# Epoch 144/200
#  - 0s - loss: 0.0021 - val_loss: 7.0191e-04
# Epoch 145/200
#  - 0s - loss: 0.0024 - val_loss: 6.8480e-04
# Epoch 146/200
#  - 0s - loss: 0.0021 - val_loss: 6.8057e-04
# Epoch 147/200
#  - 0s - loss: 0.0023 - val_loss: 7.1609e-04
# Epoch 148/200
#  - 0s - loss: 0.0019 - val_loss: 7.2189e-04
# Epoch 149/200
#  - 0s - loss: 0.0022 - val_loss: 6.7603e-04
# Epoch 150/200
#  - 0s - loss: 0.0022 - val_loss: 8.0800e-04
# Epoch 151/200
#  - 0s - loss: 0.0023 - val_loss: 6.7642e-04
# Epoch 152/200
#  - 0s - loss: 0.0022 - val_loss: 7.1112e-04
# Epoch 153/200
#  - 0s - loss: 0.0021 - val_loss: 7.6495e-04
# Epoch 154/200
#  - 0s - loss: 0.0021 - val_loss: 7.3203e-04
# Epoch 155/200
#  - 0s - loss: 0.0026 - val_loss: 8.6441e-04
# Epoch 156/200
#  - 0s - loss: 0.0021 - val_loss: 6.9038e-04
# Epoch 157/200
#  - 0s - loss: 0.0020 - val_loss: 6.7987e-04
# Epoch 158/200
#  - 0s - loss: 0.0022 - val_loss: 7.9936e-04
# Epoch 159/200
#  - 0s - loss: 0.0021 - val_loss: 6.7356e-04
# Epoch 160/200
#  - 0s - loss: 0.0023 - val_loss: 7.2716e-04
# Epoch 161/200
#  - 0s - loss: 0.0018 - val_loss: 6.7790e-04
# Epoch 162/200
#  - 0s - loss: 0.0024 - val_loss: 7.4591e-04
# Epoch 163/200
#  - 0s - loss: 0.0024 - val_loss: 7.2126e-04
# Epoch 164/200
#  - 0s - loss: 0.0021 - val_loss: 6.8909e-04
# Epoch 165/200
#  - 0s - loss: 0.0021 - val_loss: 7.6500e-04
# Epoch 166/200
#  - 0s - loss: 0.0018 - val_loss: 6.9971e-04
# Epoch 167/200
#  - 0s - loss: 0.0020 - val_loss: 7.1497e-04
# Epoch 168/200
#  - 0s - loss: 0.0021 - val_loss: 7.3628e-04
# Epoch 169/200
#  - 0s - loss: 0.0020 - val_loss: 6.8761e-04
# Epoch 170/200
#  - 0s - loss: 0.0022 - val_loss: 7.6680e-04
# Epoch 171/200
#  - 0s - loss: 0.0024 - val_loss: 8.1087e-04
# Epoch 172/200
#  - 0s - loss: 0.0021 - val_loss: 7.1148e-04
# Epoch 173/200
#  - 0s - loss: 0.0023 - val_loss: 6.9377e-04
# Epoch 174/200
#  - 0s - loss: 0.0020 - val_loss: 7.2304e-04
# Epoch 175/200
#  - 0s - loss: 0.0022 - val_loss: 6.8624e-04
# Epoch 176/200
#  - 0s - loss: 0.0019 - val_loss: 6.9225e-04
# Epoch 177/200
#  - 0s - loss: 0.0023 - val_loss: 8.4437e-04
# Epoch 178/200
#  - 0s - loss: 0.0019 - val_loss: 6.8529e-04
# Epoch 179/200
#  - 0s - loss: 0.0021 - val_loss: 9.8498e-04
# Epoch 180/200
#  - 0s - loss: 0.0021 - val_loss: 6.8420e-04
# Epoch 181/200
#  - 0s - loss: 0.0020 - val_loss: 7.5571e-04
# Epoch 182/200
#  - 0s - loss: 0.0020 - val_loss: 6.8940e-04
# Epoch 183/200
#  - 0s - loss: 0.0021 - val_loss: 9.2234e-04
# Epoch 184/200
#  - 0s - loss: 0.0020 - val_loss: 6.9518e-04
# Epoch 185/200
#  - 0s - loss: 0.0020 - val_loss: 7.0023e-04
# Epoch 186/200
#  - 0s - loss: 0.0017 - val_loss: 7.0192e-04
# Epoch 187/200
#  - 0s - loss: 0.0020 - val_loss: 6.9219e-04
# Epoch 188/200
#  - 0s - loss: 0.0017 - val_loss: 7.0782e-04
# Epoch 189/200
#  - 0s - loss: 0.0020 - val_loss: 6.8899e-04
# Epoch 190/200
#  - 0s - loss: 0.0021 - val_loss: 7.1752e-04
# Epoch 191/200
#  - 0s - loss: 0.0019 - val_loss: 7.4059e-04
# Epoch 192/200
#  - 0s - loss: 0.0021 - val_loss: 7.2625e-04
# Epoch 193/200
#  - 0s - loss: 0.0022 - val_loss: 7.7221e-04
# Epoch 194/200
#  - 0s - loss: 0.0024 - val_loss: 0.0011
# Epoch 195/200
#  - 0s - loss: 0.0020 - val_loss: 6.9317e-04
# Epoch 196/200
#  - 0s - loss: 0.0024 - val_loss: 9.2952e-04
# Epoch 197/200
#  - 0s - loss: 0.0020 - val_loss: 6.9310e-04
# Epoch 198/200
#  - 0s - loss: 0.0020 - val_loss: 7.3046e-04
# Epoch 199/200
#  - 0s - loss: 0.0023 - val_loss: 7.6895e-04
# Epoch 200/200
#  - 0s - loss: 0.0023 - val_loss: 8.1507e-04

# %% [markdown]
# ## Results
# ### Predictions and model evaluations
# The advantage of using the RMSE is that it's in the same unit as the original data, i.e. price/wk (1.000 passengers / month in Kaggle example).

# %%
def predict_and_score(model, X, Y):
    # Make predictions on the original scale of the data.
    pred = mm.inverse_transform(model.predict(X))
    # Prepare Y data to also be on the original scale for interpretability.
    orig_data = mm.inverse_transform([Y])
    # Calculate RMSE.
    score = math.sqrt(mean_squared_error(orig_data[0], pred[:, 0]))
    return(score, pred)

rmse_train, train_predict = predict_and_score(model1, train_X, train_Y)
rmse_test, test_predict = predict_and_score(model1, test_X, test_Y)

print("Training data score: %.2f RMSE" % rmse_train)
print("Test data score: %.2f RMSE" % rmse_test)
# Out:
# Training data score: 3.45 RMSE
# Test data score: 2.29 RMSE

# %% [markdown]
# ### Plotting and comparing original data, predictions, forecasts

# %%
# Start with training predictions.
train_predict_plot = np.empty_like(dataset)
train_predict_plot[:, :] = np.nan
train_predict_plot[window_size:len(train_predict) + window_size, :] = train_predict

# Add test predictions.
test_predict_plot = np.empty_like(dataset)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(train_predict) + (window_size * 2) + 1:len(dataset) - 1, :] = test_predict

# Create the plot.
plt.figure(figsize = (20, 10))
plt.plot(mm.inverse_transform(dataset), label = "True value")
plt.plot(train_predict_plot, label = "Training set prediction")
plt.plot(test_predict_plot, label = "Test set prediction")
plt.xlabel("Weeks")
plt.ylabel("GLD Price")
plt.title("Comparison true vs. predicted training / test")
plt.legend()
plt.show()
